# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# # Import Data

# %%
# importing data
kc_house_data = pd.read_csv(r'/Users/madelinegamache/Documents/Achievement 6/kc_clean.csv', index_col = False)

# %%
# Checking output
kc_house_data.head()
# Out:
#    Unnamed: 0     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0           0  221900.0         3       1.00         1180      5650     1.0
# 1           1  538000.0         3       2.25         2570      7242     2.0
# 2           2  180000.0         2       1.00          770     10000     1.0
# 3           3  604000.0         4       3.00         1960      5000     1.0
# 4           4  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
# 2           0     0          3  ...      1933             0    98028  47.7379
# 3           0     0          5  ...      1965             0    98136  47.5208
# 4           0     0          3  ...      1987             0    98074  47.6168
#
# ...

# %%
# dropping 'Unnamed: 0' column
kc_house_data = kc_house_data.drop(['Unnamed: 0'],axis=1)

# %%
# checking output
kc_house_data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  yr_built  yr_renovated  zipcode      lat  \
# 0     0          3      7  ...      1955             0    98178  47.5112
# 1     0          3      7  ...      1951          1991    98125  47.7210
# 2     0          3      6  ...      1933             0    98028  47.7379
# 3     0          5      7  ...      1965             0    98136  47.5208
# 4     0          3      8  ...      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15  year  month  day
# ...

# %%
kc_house_data.shape
# Out:
# (20939, 22)

# %%
# Checking summary statistics
kc_house_data.describe().transpose()
# Out:
#                  count           mean            std         min          25%  \
# price          20939.0  535313.546444  359359.999929  75000.0000  320000.0000
# bedrooms       20939.0       3.367592       0.907816      0.0000       3.0000
# bathrooms      20939.0       2.104148       0.761566      0.0000       1.5000
# sqft_living    20939.0    2055.163475     887.730712    290.0000    1410.0000
# sqft_lot       20939.0    9647.446105    8923.280468    520.0000    5000.0000
# floors         20939.0       1.493218       0.541480      1.0000       1.0000
# waterfront     20939.0       0.007355       0.085446      0.0000       0.0000
# view           20939.0       0.228091       0.756815      0.0000       0.0000
# condition      20939.0       3.412245       0.651438      1.0000       3.0000
# grade          20939.0       7.637566       1.157410      1.0000       7.0000
# sqft_above     20939.0    1764.089307     799.740899    290.0000    1180.0000
# ...

# %%
# Create a correlation matrix for numerical variables
corr_matrix = kc_house_data.corr()

# Visualize the correlation matrix using a heatmap
fig, ax = plt.subplots(figsize=(14, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# The following features show a positive correlation with the target variable "price" :
# "bathrooms", "sqft_living", "grade", "sqft_living15", and "sqft_above".
#
# "zipcode", "yr_built", and "condition" do not have a significant correlation with "price" and are not adding much value to the dataset. Therefore, we drop these features.

# %%
# dropping unneccessary columns for analysis 
kc_house_data = kc_house_data.drop(["zipcode", "yr_built", "condition"], axis = 1)

# %%
# Checking output
kc_house_data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  grade  sqft_above  sqft_basement  yr_renovated      lat     long  \
# 0     0      7        1180              0             0  47.5112 -122.257
# 1     0      7        2170            400          1991  47.7210 -122.319
# 2     0      6         770              0             0  47.7379 -122.233
# 3     0      7        1050            910             0  47.5208 -122.393
# 4     0      8        1680              0             0  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  year  month  day
# ...

# %%
# creating scatterplots for variables with positive correlations
sns.scatterplot(kc_house_data, x='bathrooms',y='price')
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
sns.scatterplot(kc_house_data, x='sqft_living',y='price')
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
sns.scatterplot(kc_house_data, x='grade',y='price')
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
sns.scatterplot(kc_house_data, x='sqft_above',y='price')
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %%
sns.scatterplot(kc_house_data, x='sqft_living15',y='price')
# Out:
# <Axes: xlabel='sqft_living15', ylabel='price'>

# %%
kc_house_data.shape
